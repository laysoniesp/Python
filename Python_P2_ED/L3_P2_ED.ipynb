# %% [markdown]
# # Trabalhando com Lista sequencial
#
# Uma lista sequencial, também conhecida como array ou vetor, é uma estrutura de dados que armazena elementos em posições contíguas de memória. Cada elemento da lista é identificado por um índice, que representa sua posição na lista, começando normalmente do zero. As listas sequenciais são fundamentais em várias aplicações de programação e algoritmos devido à sua eficiência em acessar elementos diretamente pelo índice.
#
# * Características principais:
#
#   **Acesso Direto**: Os elementos podem ser acessados diretamente usando o índice, o que permite operações de leitura e escrita rápidas.
#
#   **Tamanho Fixo ou Dinâmico**: Em algumas linguagens, as listas sequenciais têm tamanho fixo, enquanto em outras (como Python), elas podem ser redimensionadas dinamicamente.
#
#   **Eficiência**: Operações de leitura (acesso a um elemento específico) são realizadas em tempo constante 𝑂(1), enquanto inserções ou remoções de elementos podem variar em eficiência, dependendo da posição do elemento.
#
#
# Também é possível ir para um tutorial on-line do Python, acesse pelo link [Lista no Python](https://docs.python.org/pt-br/3/library/stdtypes.html#list). Uma outra fonte de pesquisa pode ser na Biblioteca Virtual pelo [link](https://integrada.minhabiblioteca.com.br/reader/books/9786555584288/pageid/252)

# %%
# Exemplo de uma lista sequencial em Python
lista = [10, 20, 30, 40, 50]

# Acessando o terceiro elemento (índice 2)
elemento = lista[2]  # Resultado: 30

# Modificando o valor do primeiro elemento
lista[0] = 5  # Lista se torna: [5, 20, 30, 40, 50]

# Adicionando um novo elemento ao final da lista
lista.append(60)  # Lista se torna: [5, 20, 30, 40, 50, 60]

# Removendo o segundo elemento
del lista[1]  # Lista se torna: [5, 30, 40, 50, 60]

# %%
import numpy as np

class Listasequencial:

    def __init__(self, capacidade):
        self.capacidade = capacidade
        self.ultima_posicao = -1
        self.valores = np.empty(self.capacidade, dtype=int)

    def imprime(self):
        if self.ultima_posicao == -1:
            print('O vetor está vazio')
        else:
            for i in range(self.ultima_posicao + 1):
                print(i,' - ',self.valores[i])

    def insere(self, valor):
        if self.ultima_posicao == self.capacidade - 1:
            print('Capacidade máxima atingida...')
        else:
            self.ultima_posicao += 1
            self.valores[self.ultima_posicao] = valor

    def pesquisar(self, valor):
        for i in range(self.ultima_posicao + 1):
            if (valor==self.valores[i]):
                return i
        return -1

    def excluir(self, valor):
        posicao = self.pesquisar(valor)
        if posicao == -1:
            return -1
        else:
            for i in range(posicao, self.ultima_posicao):
                self.valores[i] = self.valores[i + 1]
        self.ultima_posicao -= 1

# %%
# Criando um objeto
p1 = Listasequencial(5)

# Inserindo os valores na minha lista
p1.insere(4)
p1.insere(13)
p1.insere(5)
p1.insere(17)
p1.insere(8)

p1.imprime()

# %%
# Criando um objeto
p1 = Listasequencial(5)

# Inserindo os valores na minha lista
p1.insere(4)
p1.insere(3)
p1.insere(5)
p1.insere(7)
p1.insere(8)
p1.insere(9)
p1.insere(12)

p1.imprime()

# %%
# Criando um objeto
p1 = Listasequencial(5)

# Inserindo os valores na minha lista
p1.insere(4)
p1.insere(3)
p1.insere(5)
p1.insere(7)

p1.imprime()

# %%
p1.imprime()

# %%
# Chamando o método pesquisar para verificar se existe um valor
print('Pesquisando valores ...')
val = int(input('Informe um valor..: '))
resultado=p1.pesquisar(val)
if resultado==-1:
  print('O valor informado não existe')
else:
  print('A posição do valor ',val,' foi de',resultado)

# %%
# Excluindo um valor da minha lista
print('Excluindo um valores ...')
p1.imprime()
p1.excluir(5)
print('--------------------')
p1.imprime()

# %%
from random import randint
resposta=[]
for i in range(10):
  resposta.append(randint(10,29))

# %%
resposta

# %%
# REPOSTAS: LISTA DE EXERCÍCIO – 03 – Lista Sequencial em Python

# %%
lista_1 = Listasequencial(5)
for matricula in [101, 102, 103, 104]:
    lista_1.insere(matricula)

print("Valores armazenados:")
lista_1.imprime()
# Out:
# Valores armazenados:
# 0  -  101
# 1  -  102
# 2  -  103
# 3  -  104

# %%
lista_2 = Listasequencial(5)
for codigo in [45, 33, 27, 89, 56]:
    lista_2.insere(codigo)

print("Tentando inserir o produto 72:")
lista_2.insere(72)
# Out:
# Tentando inserir o produto 72:
# Capacidade máxima atingida...

# %%
lista_3 = Listasequencial(5)
for cliente in [11, 22, 33, 44, 55]:
    lista_3.insere(cliente)

posicao = lista_3.pesquisar(33)
if posicao != -1:
    print(f"O cliente 33 está na posição: {posicao}")
else:
    print("Cliente não encontrado.")
# Out:
# O cliente 33 está na posição: 2

# %%
lista_4 = Listasequencial(5)
for cliente in [10, 20, 30, 40, 50]:
    lista_4.insere(cliente)

lista_4.excluir(30)
print("Lista após exclusão do cliente 30:")
lista_4.imprime()
# Out:
# Lista após exclusão do cliente 30:
# 0  -  10
# 1  -  20
# 2  -  40
# 3  -  50

# %%
lista_5 = Listasequencial(5)
for senha in [5, 6, 7, 8, 9]:
    lista_5.insere(senha)

lista_5.excluir(7)
print("Lista após exclusão da senha 7:")
lista_5.imprime()
# Out:
# Lista após exclusão da senha 7:
# 0  -  5
# 1  -  6
# 2  -  8
# 3  -  9

# %%
lista_6 = Listasequencial(6)
for reserva in [101, 103, 107, 110, 115]:
    lista_6.insere(reserva)

posicao = lista_6.pesquisar(108)
if posicao != -1:
    print("A reserva 108 já foi cadastrada.")
else:
    print("A reserva 108 não consta no sistema.")
# Out:
# A reserva 108 não consta no sistema.

# %%
lista_7 = Listasequencial(5)
for pedido in [2001, 2002, 2003, 2004, 2005]:
    lista_7.insere(pedido)

lista_7.excluir(2002)
print("Lista atualizada após cancelar o pedido 2002:")
lista_7.imprime()
# Out:
# Lista atualizada após cancelar o pedido 2002:
# 0  -  2001
# 1  -  2003
# 2  -  2004
# 3  -  2005

# %%
lista_8 = Listasequencial(4)
for placa in [1234, 5678, 9101, 1213]:
    lista_8.insere(placa)

posicao = lista_8.pesquisar(5678)
if posicao != -1:
    print(f"A placa 5678 está estacionada (posição {posicao}).")
else:
    print("A placa 5678 não está estacionada.")

print("\nTentando inserir a placa 1415:")
lista_8.insere(1415)
# Out:
# A placa 5678 está estacionada (posição 1).
#
# Tentando inserir a placa 1415:
# Capacidade máxima atingida...

# %%
lista_9 = Listasequencial(5)
for nota in [70, 85, 90, 75, 60]:
    lista_9.insere(nota)

posicao = lista_9.pesquisar(75)
if posicao != -1:
    print(f"A nota 75 foi encontrada na posição {posicao}.")
else:
    print("Nota 75 não encontrada.")
# Out:
# A nota 75 foi encontrada na posição 3.

# %%
lista_10 = Listasequencial(6)
for valor in [1, 2, 3, 4, 5, 6]:
    lista_10.insere(valor)

lista_10.excluir(3)
print("Lista após excluir o valor 3:")
lista_10.imprime()

print("-" * 20)

lista_10.excluir(5)
print("Lista após excluir o valor 5:")
lista_10.imprime()
# Out:
# Lista após excluir o valor 3:
# 0  -  1
# 1  -  2
# 2  -  4
# 3  -  5
# 4  -  6
# --------------------
# Lista após excluir o valor 5:
# 0  -  1
# 1  -  2
# 2  -  4
# 3  -  6
